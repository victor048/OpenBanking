# %% [markdown]
# <a href="https://colab.research.google.com/github/victor048/OpenBanking/blob/main/api.net/products-service.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import pandas_profiling
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
import numpy as np
import json
import sys, argparse, csv

# %%
session = requests.Session()
session.headers.update({'Ocp-Apim-Subscription-Key': '543d332d2bac42a6863b55fd5ab5b79a'})
response = session.get('https://apicpqiopenbanking.azure-api.net/products-service/v1/personal-credit-cards')

# %%
print(response.status_code)

if response.status_code == 200:
    print("Funcionando perfeitamente!")
else:
    print("Resultado não encontrado!")
# Out:
# 200
# Funcionando perfeitamente!

# %%
print(response.json())
# Out:
# {'data': {'brand': {'name': 'ITAU', 'companies': [{'name': 'INVESTCRED', 'cnpjNumber': '61182408000116', 'urlComplementaryList': None, 'personalCreditCards': [{'name': 'PONTOFRIO ITAUCARD MC INTERNACIONAL', 'identification': {'product': {'type': 'STANDARD_INTERNACIONAL', 'additionalInfo': ''}, 'creditCard': {'network': 'MASTERCARD', 'additionalInfo': ''}}, 'rewardsProgram': {'hasRewardProgram': False, 'rewardProgramInfo': ''}, 'fees': {'services': [{'name': 'AVALIACAO_EMERGENCIAL_CREDITO', 'code': 'AVALIACAO_EMERGENCIAL_CREDITO', 'chargingTriggerInfo': 'Avaliação de viabilidade e de riscos para a concessão de crédito em caráter emergencial, a pedido do cliente, por meio de atendimento pessoal, para realização de despesa acima do limite do cartão, cobrada no máximo uma vez nos últimos trinta dias.', 'prices': [{'interval': '1_FAIXA_VALOR', 'value': 'NA', 'currency': 'BRL', 'customers': {'rate': 'NA'}}, {'interval': '2_FAIXA_VALOR', 'value': 'NA', 'currency': 'BRL', 'customers': {'rate
# ...

# %%
df = pd.read_csv('/content/response.csv', header=None)
df
# Out:
#                               0     ...            7197
# 0  {"data":{"brand":{"name":"ITAU"  ...  totalPages:7}}
#
# [1 rows x 7198 columns]

# %%
data = np.genfromtxt('/content/response.csv', delimiter=',', skip_header=10,
                     skip_footer=10, names=['x', 'y', 'z'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: genfromtxt: Empty input file: "/content/response.csv"

# %%
data
# Out:
# array([], dtype=[('x', '<f8'), ('y', '<f8'), ('z', '<f8')])

# %%
with open('response.csv', 'r') as csv:
     first_line = csv.readline()
     your_data = csv.readlines()

ncol = first_line.count(',') 
ncol
# Out:
# 7197

# %%
df[' a pedido do cliente.2']
# Out:
# Series([], Name:  a pedido do cliente.2, dtype: object)
